# %%
import pandas as pd

# %%
import requests

url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=frequentation-gares&q=paris&sort=nom_gare&facet=nom_gare&facet=code_postal&facet=segmentation_drg"
response = requests.get(url)
data = response.json()

gares = []

coordonnees = {
    "Paris Austerlitz": (48.840609, 2.366563),
    "Paris Bercy": (48.840889, 2.381641),
    "Paris Est": (48.876576, 2.359084),
    "Paris Gare de Lyon": (48.844512, 2.373522),
    "Paris Gare du Nord": (48.880931, 2.355158),
    "Paris Montparnasse": (48.840847, 2.319543),
    "Paris Saint-Lazare": (48.876141, 2.326190)
}

if "records" in data:
    for record in data["records"]:
        gare_info = {
            "nom_gare": record["fields"]["nom_gare"],
            "frequentation_2019": record["fields"]["total_voyageurs_2019"],
            "frequentation_2020": record["fields"]["total_voyageurs_2020"],
            "frequentation_2021": record["fields"]["total_voyageurs_2021"],
        }

        if gare_info["nom_gare"] == "Paris Bercy Bourgogne - Pays d'Auvergne":
            gare_info["nom_gare"] = "Paris Bercy"

        if gare_info["nom_gare"] in coordonnees:
            gare_info["latitude"], gare_info["longitude"] = coordonnees[gare_info["nom_gare"]]

        frequentation_moyenne = (gare_info["frequentation_2019"] + gare_info["frequentation_2020"] + gare_info["frequentation_2021"]) // 3
        gare_info["frequentation_2022"] = frequentation_moyenne

        gares.append(gare_info)

        print(response.status_code)

# %%
df_freq_gare = pd.DataFrame(gares)

# %%
df_freq_gare.to_csv("frequentations_gare.csv", index=False)

# %%
df_freq_gare
# Out:
#              nom_gare  frequentation_2019  frequentation_2020  \
# 1    Paris Austerlitz            21682820            13203603
# 2         Paris Bercy             4318464             2498330
# 3           Paris Est            41240098            21580625
# 4  Paris Gare de Lyon           112644337            55824824
# 5  Paris Gare du Nord           244759909            92236287
# 6  Paris Montparnasse            61374035            32439307
# 7  Paris Saint-Lazare           107340421           114468385
#
#    frequentation_2021  frequentation_2022   latitude  longitude
# 1            22281301            19055908  48.840609   2.366563
# 2             3347763             3388185  48.840889   2.381641
# 3            27758686            30193136  48.876576   2.359084
# 4            79986275            82818478  48.844512   2.373522
# 5           126622180           154539458  48.880931   2.355158
# 6            41043477            44952273  48.840847   2.319543
# 7            91502192           104436999  48.876141   2.326190
