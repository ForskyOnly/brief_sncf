# %%
import requests
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Requétes et reccupération des données des objets perdu dans les gares de Paris

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2019&refine.gc_obo_gare_origine_r_name=Paris+Gare+de+Lyon"
data = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gare_lyon19 = pd.DataFrame(data)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2019&refine.gc_obo_gare_origine_r_name=Paris+Montparnasse"
data1 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data1.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
mtparnass19 = pd.DataFrame(data1)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2019&refine.gc_obo_gare_origine_r_name=Paris+Gare+du+Nord"
data2 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data2.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gdnord19 = pd.DataFrame(data2)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2019&refine.gc_obo_gare_origine_r_name=Paris+Saint-Lazare"
data3 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data3.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
stlaz19 =pd.DataFrame(data3)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2019&refine.gc_obo_gare_origine_r_name=Paris+Est"
data4 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data4.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
est19 = pd.DataFrame(data4)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2019&refine.gc_obo_gare_origine_r_name=Paris+Bercy"
data5 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data5.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
bercy19 = pd.DataFrame(data5)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2019&refine.gc_obo_gare_origine_r_name=Paris+Austerlitz"
data6 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data6.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
aust19 = pd.DataFrame(data6)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.gc_obo_gare_origine_r_name=Paris+Austerlitz&refine.gc_obo_date_heure_restitution_c=2020"
data7 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data7.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
aust20 = pd.DataFrame(data7)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2020&refine.gc_obo_gare_origine_r_name=Paris+Bercy"
data8 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data8.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
bercy20 = pd.DataFrame(data8)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2020&refine.gc_obo_gare_origine_r_name=Paris+Est"
data9 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data9.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
est20 = pd.DataFrame(data9)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2020&refine.gc_obo_gare_origine_r_name=Paris+Saint-Lazare"
data10 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data10.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
stlaz20 = pd.DataFrame(data10)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2020&refine.gc_obo_gare_origine_r_name=Paris+Gare+du+Nord"
data11 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data11.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gdnord20 = pd.DataFrame(data11)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2020&refine.gc_obo_gare_origine_r_name=Paris+Montparnasse"
data13 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data13.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
mtparnass20 = pd.DataFrame(data13)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2020&refine.gc_obo_gare_origine_r_name=Paris+Gare+de+Lyon"
data12 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data12.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gare_lyon20 = pd.DataFrame(data12)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2021&refine.gc_obo_gare_origine_r_name=Paris+Montparnasse"
data14 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data14.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
mtparnass21 = pd.DataFrame(data14)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2021&refine.gc_obo_gare_origine_r_name=Paris+Gare+de+Lyon"
data15 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data15.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gare_lyon21 = pd.DataFrame(data15)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2021&refine.gc_obo_gare_origine_r_name=Paris+Saint-Lazare"
data16 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data16.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
stlaz21 = pd.DataFrame(data16)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2021&refine.gc_obo_gare_origine_r_name=Paris+Gare+du+Nord"
data17 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data17.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gdnord21 = pd.DataFrame(data17)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2021&refine.gc_obo_gare_origine_r_name=Paris+Est"
data18 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data18.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
est21 = pd.DataFrame(data18)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2021&refine.gc_obo_gare_origine_r_name=Paris+Austerlitz"
data19 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data19.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
aust21 = pd.DataFrame(data19)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2021&refine.gc_obo_gare_origine_r_name=Paris+Bercy"
data20 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data20.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
bercy21 = pd.DataFrame(data20)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2022&refine.gc_obo_gare_origine_r_name=Paris+Gare+de+Lyon"
data21 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data21.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gare_lyon22 = pd.DataFrame(data21)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2022&refine.gc_obo_gare_origine_r_name=Paris+Montparnasse"
data22 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data22.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
mtparnass22 = pd.DataFrame(data22)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2022&refine.gc_obo_gare_origine_r_name=Paris+Saint-Lazare"
data23 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data23.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
stlaz22 = pd.DataFrame(data23)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2022&refine.gc_obo_gare_origine_r_name=Paris+Gare+du+Nord"
data24 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data24.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
gdnord22 = pd.DataFrame(data24)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2022&refine.gc_obo_gare_origine_r_name=Paris+Est"
data25 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data25.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
est22 = pd.DataFrame(data25)

# %%
url = "https://ressources.data.sncf.com//api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2022&refine.gc_obo_gare_origine_r_name=Paris+Austerlitz"
data26 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data26.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
aust22 = pd.DataFrame(data26)

# %%
url = "https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=paris&sort=date&facet=date&facet=gc_obo_date_heure_restitution_c&facet=gc_obo_gare_origine_r_name&facet=gc_obo_nature_c&facet=gc_obo_type_c&facet=gc_obo_nom_recordtype_sc_c&refine.date=2022&refine.gc_obo_gare_origine_r_name=Paris+Bercy"
data27 = []

start = 0
rows = 50
total_records = None

while total_records is None or start < total_records:
    response = requests.get(url, params={"rows": rows, "start": start})
    
    if response.status_code == 200:
        response_json = response.json()
        records = response_json["records"]
        total_records = response_json["nhits"]
        
        for record in records:
            objet_trouve = {
                "Code gare": record["fields"]["gc_obo_gare_origine_r_code_uic_c"],
                "Nom gare": record["fields"]["gc_obo_gare_origine_r_name"],
                "Type d'objet": record["fields"]["gc_obo_type_c"],
                "Nature de l'objet": record["fields"]["gc_obo_nature_c"],
                "Type d'enregistrement": record["fields"]["gc_obo_nom_recordtype_sc_c"],
                "Date": record["fields"]["date"]
            }
            data27.append(objet_trouve)
        
        start += rows
    
    else:
        print(response.status_code)
        break

# %%
bercy22 = pd.DataFrame(data27)

# %% [markdown]
# ### Creation d'un DF unique regroupant tout les données de gares

# %%
df_objet_perdus = pd.concat([bercy19,bercy20,bercy21,bercy22,aust19,aust20,aust21,aust22,gare_lyon19,gare_lyon20,gare_lyon21,gare_lyon22,mtparnass19,mtparnass20,mtparnass21,mtparnass22,stlaz19,stlaz20,stlaz21,stlaz22,est19,est20,est21,est22,gdnord19,gdnord20,gdnord21,gdnord22])

# %% [markdown]
# ### Modification du format Date pour rendre les données cohérente avec la base de données et les autre DF

# %%
df_objet_perdus["Date"] = pd.to_datetime(df_objet_perdus["Date"])
df_objet_perdus["Date"] = df_objet_perdus["Date"].dt.strftime("%Y-%m-%d")

# %%
df_objet_perdus
# Out:
#        Code gare            Nom gare  \
# 0     0087686667         Paris Bercy
# 1     0087686667         Paris Bercy
# 2     0087686667         Paris Bercy
# 3     0087686667         Paris Bercy
# 4     0087686667         Paris Bercy
# ...          ...                 ...
# 3604  0087271007  Paris Gare du Nord
# 3605  0087271007  Paris Gare du Nord
# 3606  0087271007  Paris Gare du Nord
# 3607  0087271007  Paris Gare du Nord
# 3608  0087271007  Paris Gare du Nord
#
#                                       Type d'objet  \
# 0     Porte-monnaie / portefeuille, argent, titres
# 1              Bagagerie: sacs, valises, cartables
# 2              Bagagerie: sacs, valises, cartables
# 3              Bagagerie: sacs, valises, cartables
# 4                            Vêtements, chaussures
# ...                                            ...
# 3604  Porte-monnaie / portefeuille, argent, titres
# 3605  Porte-monnaie / portefeuille, argent, titres
# ...

# %%
df_objet_perdus = df_objet_perdus.reset_index()
df_objet_perdus.index += 1
df_objet_perdus = df_objet_perdus.drop(columns=['index'])

# %% [markdown]
# ### Suppression des colonnes inutiles

# %%
df_objet_perdus = df_objet_perdus.drop("Code gare",axis=1)

# %%
df_objet_perdus = df_objet_perdus.drop("Type d'enregistrement",axis=1)

# %%
df_objet_perdus
# Out:
#                  Nom gare                                  Type d'objet  \
# 1             Paris Bercy  Porte-monnaie / portefeuille, argent, titres
# 2             Paris Bercy           Bagagerie: sacs, valises, cartables
# 3             Paris Bercy           Bagagerie: sacs, valises, cartables
# 4             Paris Bercy           Bagagerie: sacs, valises, cartables
# 5             Paris Bercy                         Vêtements, chaussures
# ...                   ...                                           ...
# 81569  Paris Gare du Nord  Porte-monnaie / portefeuille, argent, titres
# 81570  Paris Gare du Nord  Porte-monnaie / portefeuille, argent, titres
# 81571  Paris Gare du Nord  Porte-monnaie / portefeuille, argent, titres
# 81572  Paris Gare du Nord           Bagagerie: sacs, valises, cartables
# 81573  Paris Gare du Nord  Porte-monnaie / portefeuille, argent, titres
#
#                                     Nature de l'objet        Date
# ...

# %%
df_objet_perdus.to_csv("objet_perdus.csv")
